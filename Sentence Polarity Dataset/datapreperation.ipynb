# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd
import numpy as np

df1=pd.read_csv("/content/gdrive/My Drive/Colab Notebooks/Masters Project/Sentence Polarity Dataset/rt-polarity.pos",sep="|",names=['text'], header=None,encoding='latin-1')
df1['label']=1
df1.head()
# Out:
#                                                 text  label
# 0  the rock is destined to be the 21st century's ...      1
# 1  the gorgeously elaborate continuation of " the...      1
# 2                     effective but too-tepid biopic      1
# 3  if you sometimes like to go to the movies to h...      1
# 4  emerges as something rare , an issue movie tha...      1

# %%
df2=pd.read_csv("/content/gdrive/My Drive/Colab Notebooks/Masters Project/Sentence Polarity Dataset/rt-polarity.neg",sep="|",names=['text'], header=None,encoding='latin-1')
df2['label']=0
df2.head()
# Out:
#                                                 text  label
# 0                  simplistic , silly and tedious .       0
# 1  it's so laddish and juvenile , only teenage bo...      0
# 2  exploitative and largely devoid of the depth o...      0
# 3  [garbus] discards the potential for pathologic...      0
# 4  a visually flashy but narratively opaque and e...      0

# %%
df1=df1.sample(n=1000)
df2=df2.sample(n=1000)

# %%
df=pd.concat([df1,df2])
df.head()
# Out:
#                                                    text  label
# 564    " antwone fisher " is an earnest , by-the-num...      1
# 4248  this often-hilarious farce manages to generate...      1
# 3851  a pure participatory event that malnourished i...      1
# 3113  meyjes . . . has done his homework and soaked ...      1
# 3963  the word that comes to mind , while watching e...      1

# %%
print(df.count())
print(df.label.value_counts())
# Out:
# text     2000
# label    2000
# dtype: int64
# 1    1000
# 0    1000
# Name: label, dtype: int64

# %%
df = df.sample(frac = 1) 
df.to_csv("/content/gdrive/My Drive/Colab Notebooks/Masters Project/Sentence Polarity Dataset/sentimentpolarity.csv",index=False)
